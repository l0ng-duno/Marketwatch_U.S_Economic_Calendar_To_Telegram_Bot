# %%
import numpy as np
import pandas as pd
import requests

df = pd.read_html('https://www.marketwatch.com/economy-politics/calendar?mod=economy-politics')
df_0 = df[0]
df_0.drop(['Period','Actual','Median Forecast','Previous'],axis='columns',inplace=True)
df_0
# Out:
#             Time (ET)                                             Report
# 0      MONDAY, DEC. 6                                                NaN
# 1                 NaN                                     None scheduled
# 2     TUESDAY, DEC. 7                                                NaN
# 3             8:30 am                                      Trade deficit
# 4             8:30 am                       Productivity revision (SAAR)
# 5             8:30 am                   Unit labor costs revision (SAAR)
# 6                3 pm                   Consumer credit (monthly change)
# 7   WEDNESDAY, DEC. 8                                                NaN
# 8               10 am                                       Job openings
# 9               10 am                                          Job quits
# 10   THURSDAY, DEC. 9                                                NaN
# 11            8:30 am     Initial jobless claims (regular state program)
# 12            8:30 am  Continuing jobless claims (regular state program)
# 13              10 am                   Wholesale inventories (revision)
# 14            12 noon                              Real household wealth
# 15            12 noon                    Real domestic nonfinancial debt
# 16    FRIDAY, DEC. 10                                                NaN
# 17            8:30 am                               Consumer price index
# 18            8:30 am                                     Core inflation
# 19            8:30 am                        CPI (year-over-year change)
# 20              10 am       UMich consumer sentiment index (preliminary)
# 21              10 am       Expected inflation, five-years (preliminary)
# 22               2 pm                                     Federal budget

# %%
df_1 = df[1]
df_1.drop(['Period','Actual','Median Forecast','Previous'],axis='columns',inplace=True)
df_1
# Out:
#              Time (ET)                                             Report
# 0      MONDAY, DEC. 13                                                NaN
# 1                  NaN                                     None scheduled
# 2     TUESDAY, DEC. 14                                                NaN
# 3                 6 am                          NFIB small-business index
# 4              8:30 am                               Producer price index
# 5   WEDNESDAY, DEC. 15                                                NaN
# 6              8:30 am                                       Retail sales
# 7              8:30 am                       Retail sales excluding autos
# 8              8:30 am                                 Import price index
# 9              8:30 am                 Import price index excluding fuels
# 10             8:30 am                   Empire State manufacturing index
# 11               10 am                          NAHB home builders' index
# 12               10 am                               Business inventories
# 13                2 pm                  Federal Reserve FOMC announcement
# 14             2:30 pm                     Jerome Powell press conference
# 15   THURSDAY, DEC. 16                                                NaN
# 16             8:30 am     Initial jobless claims (regular state program)
# 17             8:30 am  Continuing jobless claims (regular state program)
# 18             8:30 am                            Building permits (SAAR)
# 19             8:30 am                              Housing starts (SAAR)
# 20             8:30 am               Philadelphia Fed manufacturing index
# 21             9:15 am                        Industrial production index
# 22             9:15 am                               Capacity utilization
# 23     FRIDAY, DEC. 17                                                NaN
# 24                 NaN                                     None scheduled

# %%
fname = open('bot_token.txt','r')
list_token =[]

for line in fname:
    line = line.split()
    list_token.append(line)

token = list_token[0]
chat_id =list_token[1]
token = token[2]
chat_id =chat_id[2]

# %%
base_url_0= (f'https://api.telegram.org/bot{token}/sendMessage?chat_id={chat_id}&text="{df_0}"')
requests.get(base_url_0)

base_url_1= (f'https://api.telegram.org/bot{token}/sendMessage?chat_id={chat_id}&text="{df_1}"')
requests.get(base_url_1)
# Out:
# <Response [200]>
